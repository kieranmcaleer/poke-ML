# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import sklearn
import pandas as pd

# %%
poke_csv="Resources/clean_data.csv"
poke_df= pd.read_csv(poke_csv)
poke_df
# Out:
#        #                   Name    Type1   Type2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
short_df=poke_df.drop(["Total", "HP", "Attack", "Defense", "SpAtk", "SpDef", "Speed", "Legendary"], axis=1)
short_df
# Out:
#        #                   Name    Type1   Type2  Generation
# 0      1              Bulbasaur    Grass  Poison           1
# 1      2                Ivysaur    Grass  Poison           1
# 2      3               Venusaur    Grass  Poison           1
# 3      3  VenusaurMega Venusaur    Grass  Poison           1
# 4      4             Charmander     Fire     NaN           1
# ..   ...                    ...      ...     ...         ...
# 795  719                Diancie     Rock   Fairy           6
# 796  719    DiancieMega Diancie     Rock   Fairy           6
# 797  720    HoopaHoopa Confined  Psychic   Ghost           6
# 798  720     HoopaHoopa Unbound  Psychic    Dark           6
# 799  721              Volcanion     Fire   Water           6
#
# [800 rows x 5 columns]

# %%
#Clean the dataframe to include only relevant columns and create a recode column for each type 
short_df["Type1_Recode"] = ""
short_df["Type2_Recode"] = ""
short_df
# Out:
#        #                   Name    Type1   Type2  Generation Type1_Recode  \
# 0      1              Bulbasaur    Grass  Poison           1
# 1      2                Ivysaur    Grass  Poison           1
# 2      3               Venusaur    Grass  Poison           1
# 3      3  VenusaurMega Venusaur    Grass  Poison           1
# 4      4             Charmander     Fire     NaN           1
# ..   ...                    ...      ...     ...         ...          ...
# 795  719                Diancie     Rock   Fairy           6
# 796  719    DiancieMega Diancie     Rock   Fairy           6
# 797  720    HoopaHoopa Confined  Psychic   Ghost           6
# 798  720     HoopaHoopa Unbound  Psychic    Dark           6
# 799  721              Volcanion     Fire   Water           6
#
#     Type2_Recode
# 0
# 1
# 2
# 3
# 4
# ..           ...
# 795
# 796
# 797
# 798
# 799
#
# [800 rows x 7 columns]

# %%
#Gather list of unique pokemon types
type1_list = short_df["Type1"].unique()
type1_list
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %%
#Confirm number of unique types
len(type1_list)
# Out:
# 18

# %%
#iterate through DF to recode the listed type1 for each pokemon 
for row,col in short_df.iterrows(): 
    if short_df["Type1"][row] == "Grass": 
        short_df["Type1_Recode"][row] = 1
    elif short_df["Type1"][row] == "Fire": 
        short_df["Type1_Recode"][row] = 2
    elif short_df["Type1"][row] == "Water": 
        short_df["Type1_Recode"][row] = 3
    elif short_df["Type1"][row] == "Bug": 
        short_df["Type1_Recode"][row] = 4
    elif short_df["Type1"][row] == "Normal": 
        short_df["Type1_Recode"][row] = 5
    elif short_df["Type1"][row] == "Poison": 
        short_df["Type1_Recode"][row] = 6
    elif short_df["Type1"][row] == "Electric": 
        short_df["Type1_Recode"][row] = 7
    elif short_df["Type1"][row] == "Ground": 
        short_df["Type1_Recode"][row] = 8
    elif short_df["Type1"][row] == "Fairy": 
        short_df["Type1_Recode"][row] = 9
    elif short_df["Type1"][row] == "Fighting": 
        short_df["Type1_Recode"][row] = 10
    elif short_df["Type1"][row] == "Psychic": 
        short_df["Type1_Recode"][row] = 11
    elif short_df["Type1"][row] == "Rock": 
        short_df["Type1_Recode"][row] = 12
    elif short_df["Type1"][row] == "Ghost": 
        short_df["Type1_Recode"][row] = 13
    elif short_df["Type1"][row] == "Ice": 
        short_df["Type1_Recode"][row] = 14
    elif short_df["Type1"][row] == "Dragon": 
        short_df["Type1_Recode"][row] = 15
    elif short_df["Type1"][row] == "Dark": 
        short_df["Type1_Recode"][row] = 16
    elif short_df["Type1"][row] == "Steel": 
        short_df["Type1_Recode"][row] = 17
    elif short_df["Type1"][row] == "Flying": 
        short_df["Type1_Recode"][row] = 18
        
short_df
# Out:
# C:\Users\Kieran\anaconda3\envs\PythonAdv\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\Kieran\anaconda3\envs\PythonAdv\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Kieran\anaconda3\envs\PythonAdv\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
#iterate through DF to recode the listed type2 for each pokemon 
for row,col in short_df.iterrows(): 
    if short_df["Type2"][row] == "Grass": 
        short_df["Type2_Recode"][row] = 1
    elif short_df["Type2"][row] == "Fire": 
        short_df["Type2_Recode"][row] = 2
    elif short_df["Type2"][row] == "Water": 
        short_df["Type2_Recode"][row] = 3
    elif short_df["Type2"][row] == "Bug": 
        short_df["Type2_Recode"][row] = 4
    elif short_df["Type2"][row] == "Normal": 
        short_df["Type2_Recode"][row] = 5
    elif short_df["Type2"][row] == "Poison": 
        short_df["Type2_Recode"][row] = 6
    elif short_df["Type2"][row] == "Electric": 
        short_df["Type2_Recode"][row] = 7
    elif short_df["Type2"][row] == "Ground": 
        short_df["Type2_Recode"][row] = 8
    elif short_df["Type2"][row] == "Fairy": 
        short_df["Type2_Recode"][row] = 9
    elif short_df["Type2"][row] == "Fighting": 
        short_df["Type2_Recode"][row] = 10
    elif short_df["Type2"][row] == "Psychic": 
        short_df["Type2_Recode"][row] = 11
    elif short_df["Type2"][row] == "Rock": 
        short_df["Type2_Recode"][row] = 12
    elif short_df["Type2"][row] == "Ghost": 
        short_df["Type2_Recode"][row] = 13
    elif short_df["Type2"][row] == "Ice": 
        short_df["Type2_Recode"][row] = 14
    elif short_df["Type2"][row] == "Dragon": 
        short_df["Type2_Recode"][row] = 15
    elif short_df["Type2"][row] == "Dark": 
        short_df["Type2_Recode"][row] = 16
    elif short_df["Type2"][row] == "Steel": 
        short_df["Type2_Recode"][row] = 17
    elif short_df["Type2"][row] == "Flying": 
        short_df["Type2_Recode"][row] = 18
        
short_df
# Out:
# C:\Users\Kieran\anaconda3\envs\PythonAdv\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Kieran\anaconda3\envs\PythonAdv\lib\site-packages\ipykernel_launcher.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\Kieran\anaconda3\envs\PythonAdv\lib\site-packages\ipykernel_launcher.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
short_df.to_csv(r'./Resources/poke_recode.csv', index = False, header=True)

# %%
poke_df
# Out:
#        #                   Name    Type1   Type2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder
# making a specific dataframe to predict legendary or not
poke_df.dropna()
stats_df = poke_df[["Total","HP","Attack","Defense","SpAtk","SpDef", "Speed"]]
poke_df= poke_df.Legendary.astype(int)


# split them into an x and y
X=stats_df
y=poke_df

# %%
from sklearn.model_selection import train_test_split

# %%
# train test split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=.2)

# %%
# get linear regression
from sklearn.linear_model import LinearRegression

# %%
clf = LinearRegression()

# %%
# fit the data 
clf.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
# predict the model
clf.predict(X_test)
# Out:
# array([-0.02320837,  0.05163823,  0.20403252,  0.23932923,  0.13740627,
#        -0.17644783, -0.10774194, -0.03734892,  0.03852028, -0.07251547,
#         0.26305873,  0.39289165,  0.0741263 ,  0.17226639,  0.26724911,
#         0.18389662, -0.03135218,  0.10763052,  0.17551979, -0.00103189,
#        -0.04691042, -0.0427426 , -0.11623572, -0.09261363, -0.0063731 ,
#        -0.08381058,  0.1367344 , -0.08201654, -0.03900061,  0.14011543,
#         0.16708413, -0.1460907 , -0.00182771,  0.1184845 ,  0.12685758,
#        -0.00487954,  0.1701166 ,  0.04729959,  0.10657578,  0.04299815,
#        -0.17360708,  0.11037499, -0.10425465,  0.1006122 ,  0.1090084 ,
#        -0.03201768,  0.13456876,  0.0729499 ,  0.0709406 , -0.0241006 ,
#         0.08144171,  0.21011552,  0.08328441,  0.0739521 , -0.07004578,
#        -0.04343327, -0.01936717,  0.09350991,  0.22718968, -0.03634991,
#         0.00571714,  0.13145555,  0.18480972,  0.03659383, -0.08432386,
# ...

# %%
# check the score of the model

clf.score(X_test, y_test)
# Out:
# 0.16992238211509947
